# %%
import sys

# %%
sys.path.append('.')

# %%
import tools_graph
import tools_data

# %%
experiment_set = "data/freqV3"
experiments = tools_data.getExperimentsInSet(experiment_set)
experiments.reverse()

# %%
experiments
# Out:
# ['5_1000_1000_1_0_0_0_20210914_0938',
#  '5_100_9000_1_0_0_0_20210914_1007',
#  '5_10_90000_1_0_0_0_20210914_1035',
#  '5_6_180000_1_0_0_0_20210914_1132',
#  '5_8_112500_1_0_0_0_20210914_1104']

# %%
for experiment in experiments:
    print(experiment)
    consumer = tools_data.readConsumer(experiment_set, experiment)
    device_aggregate = tools_data.readAggregateDevices(experiment_set, experiment)
    tools_graph.graphType1(device_aggregate, consumer, experiment)
    tools_graph.graphType2(consumer, experiment)
# Out:
# 5_1000_1000_1_0_0_0_20210914_0938
# 5_100_9000_1_0_0_0_20210914_1007
# 5_10_90000_1_0_0_0_20210914_1035
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# 5_6_180000_1_0_0_0_20210914_1132
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# 5_8_112500_1_0_0_0_20210914_1104
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
tools_graph.graphType3(experiment_set, 3, "Subscriptions", experiment_set, lambda params: int(params[3]))
# Out:
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
tools_graph.graphType4(experiment_set, 3, "Subscriptions", experiment_set, lambda params: int(params[3]))
# Out:
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/monte97/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
