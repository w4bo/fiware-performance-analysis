# %%
import sys
sys.path.append('.')

# %%
import tools_data
import tools_graphv2

# %%
EXP_V = "V6"

# %%
data_folder = "data"

# %% [markdown]
# ---
# # Time Count

# %% [markdown]
# ## Device

# %%
tools_graphv2.graphMatrixTimeCount("{}/{}/DEVICE_{}".format(data_folder,EXP_V, EXP_V), 0, [1,3,6], lambda params: "Devices = {} ({} messages per second)".format(params[0], int(params[0]*(1000/params[1])*params[3])))
# Out:
# data/V6/DEVICE_V6
# 1_200_4500_1_0_0_1000_20210920_201356
# 10_200_4500_1_0_0_1000_20210920_203622
# 25_200_4500_1_0_0_1000_20210920_205955
# 50_200_4500_1_0_0_1000_20210920_212423
# 100_200_4500_1_0_0_1000_20210920_215127
# 125_200_4500_1_0_0_1000_20210920_222322

# %% [markdown]
# ## Frequency

# %%
tools_graphv2.graphMatrixTimeCount("{}/{}/FREQUENCY_{}".format(data_folder, EXP_V, EXP_V), 1, [0,3,6], lambda params: "Period = {}ms ({} messages per second)".format(params[1], int(params[0]*(1000/params[1])*params[3])), ascending=False)
# Out:
# data/V6/FREQUENCY_V6
# 5_1000_1000_1_0_0_1000_20210920_225521
# 5_100_9000_1_0_0_1000_20210920_232019
# 5_40_22500_1_0_0_1000_20210920_234342
# 5_20_45000_1_0_0_1000_20210921_000714
# 5_10_90000_1_0_0_1000_20210921_003039
# 5_8_112500_1_0_0_1000_20210921_005408

# %% [markdown]
# ## Payload

# %%
tools_graphv2.graphMatrixTimeCount("{}/{}/PAYLOAD_{}".format(data_folder, EXP_V, EXP_V), 6, [0,1,3], lambda params: "Payload = {}Byte".format(params[6]))
# Out:
# data/V6/PAYLOAD_V6
# 50_200_4500_1_0_0_1000_20210921_011803
# 50_200_4500_1_0_0_10000_20210921_014415
# 50_200_4500_1_0_0_50000_20210921_021033
# 50_200_4500_1_0_0_100000_20210921_023752

# %% [markdown]
# ## Subscriptions

# %% [markdown]
# 1 2 3 4 5 10

# %%
tools_graphv2.graphMatrixTimeCount("{}/{}/SUB_{}".format(data_folder, EXP_V, EXP_V), 3, [0,1,6], lambda params: "Subscriptions = {} ({} messages per second)".format(params[3], int(params[0]*(1000/params[1])*params[3])))
# Out:
# data/V6/SUB_V6
# 25_200_4500_1_0_0_1000_20210921_095919
# 25_200_4500_5_0_0_1000_20210921_102437
# 25_200_4500_10_0_0_1000_20210921_104945
# 25_200_4500_15_0_0_1000_20210921_111513
# 25_200_4500_20_0_0_1000_20210921_113946
# 25_200_4500_25_0_0_1000_20210921_120424
# 25_200_4500_30_0_0_1000_20210921_122921

# %% [markdown]
# ---
# # Time delay

# %% [markdown]
# ## Device

# %%
tools_graphv2.graphMatrixTimeDelay("{}/{}/DEVICE_{}".format(data_folder, EXP_V, EXP_V), 0, [1,3,6], lambda params: "Devices = {} ({} messages per second)".format(params[0], int(params[0]*(1000/params[1])*params[3])))
# Out:
# data/V6/DEVICE_V6
# 1_200_4500_1_0_0_1000_20210920_201356
# 10_200_4500_1_0_0_1000_20210920_203622
# 25_200_4500_1_0_0_1000_20210920_205955
# 50_200_4500_1_0_0_1000_20210920_212423
# 100_200_4500_1_0_0_1000_20210920_215127
# 125_200_4500_1_0_0_1000_20210920_222322

# %% [markdown]
# ## Frequency

# %%
tools_graphv2.graphMatrixTimeDelay("{}/{}/FREQUENCY_{}".format(data_folder, EXP_V, EXP_V), 1, [0,3,6], lambda params: "Period = {}ms ({} messages per second)".format(params[1], int(params[0]*(1000/params[1])*params[3])))
# Out:
# data/V6/FREQUENCY_V6
# 5_8_112500_1_0_0_1000_20210921_005408
# 5_10_90000_1_0_0_1000_20210921_003039
# 5_20_45000_1_0_0_1000_20210921_000714
# 5_40_22500_1_0_0_1000_20210920_234342
# 5_100_9000_1_0_0_1000_20210920_232019
# 5_1000_1000_1_0_0_1000_20210920_225521

# %% [markdown]
# ## Payload

# %%
tools_graphv2.graphMatrixTimeDelay("{}/{}/PAYLOAD_{}".format(data_folder, EXP_V, EXP_V), 6, [0,1,3], lambda params: "Payload = {}Byte".format(params[6]))
# Out:
# data/V6/PAYLOAD_V6
# 50_200_4500_1_0_0_1000_20210921_011803
# 50_200_4500_1_0_0_10000_20210921_014415
# 50_200_4500_1_0_0_50000_20210921_021033
# 50_200_4500_1_0_0_100000_20210921_023752

# %% [markdown]
# ## Subscriptions

# %%
tools_graphv2.graphMatrixTimeDelay("{}/{}/SUB_{}".format(data_folder, EXP_V, EXP_V), 3, [0,1,6], lambda params: "Subscriptions = {} ({} messages per second)".format(params[3], int(params[0]*(1000/params[1])*params[3])))
# Out:
# data/V6/SUB_V6
# 25_200_4500_1_0_0_1000_20210921_095919
# 25_200_4500_5_0_0_1000_20210921_102437
# 25_200_4500_10_0_0_1000_20210921_104945
# 25_200_4500_15_0_0_1000_20210921_111513
# 25_200_4500_20_0_0_1000_20210921_113946
# 25_200_4500_25_0_0_1000_20210921_120424
# 25_200_4500_30_0_0_1000_20210921_122921

# %% [markdown]
# ---
# # Cumulative

# %% [markdown]
# ## Frequency

# %%
tools_graphv2.cumulative("{}/{}/FREQUENCY_{}".format(data_folder, EXP_V, EXP_V), "Messages per second", "Ratio", tools_data.paramsToMessageCount, lambda consumer, devices: consumer.shape[0] / devices.shape[0])

# %%
tools_graphv2.cumulative("{}/{}/FREQUENCY_{}".format(data_folder, EXP_V, EXP_V), "Messages per second", "Delay (ms)", tools_data.paramsToMessageCount, lambda consumer, devices: consumer["Delay Consumer/Device"].mean())

# %% [markdown]
# ## Devices

# %%
tools_graphv2.cumulative("{}/{}/DEVICE_{}".format(data_folder, EXP_V, EXP_V), "Messages per second", "Ratio", tools_data.paramsToMessageCount, lambda consumer, devices: consumer.shape[0] / devices.shape[0])

# %%
tools_graphv2.cumulative("{}/{}/DEVICE_{}".format(data_folder, EXP_V, EXP_V), "Messages per second", "Delay (ms)", tools_data.paramsToMessageCount, lambda consumer, devices: consumer["Delay Consumer/Device"].mean())

# %% [markdown]
# ## Subscriptions

# %%
tools_graphv2.cumulative("{}/{}/SUB_{}".format(data_folder, EXP_V, EXP_V), "Messages per second", "Ratio", tools_data.paramsToMessageCount, lambda consumer, devices: consumer.shape[0] / devices.shape[0])

# %%
tools_graphv2.cumulative("{}/{}/SUB_{}".format(data_folder, EXP_V, EXP_V), "Messages per second", "Delay (ms)", tools_data.paramsToMessageCount, lambda consumer, devices: consumer["Delay Consumer/Device"].mean())

# %% [markdown]
# ## Payload

# %%
tools_graphv2.cumulative("{}/{}/PAYLOAD_{}".format(data_folder, EXP_V, EXP_V), "Payload (Byte)", "Ratio", lambda params: params[6], lambda consumer, devices: consumer.shape[0] / devices.shape[0])

# %%
tools_graphv2.cumulative("{}/{}/PAYLOAD_{}".format(data_folder, EXP_V, EXP_V), "Payload (Byte)", "Delay (ms)", lambda params: params[6], lambda consumer, devices: consumer["Delay Consumer/Device"].mean())

# %% [markdown]
# 5 messaggi al secondo, 1 MB di dati
