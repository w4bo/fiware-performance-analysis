# %%
import sys

# %%
sys.path.append('.')

# %%
import tools_graph
import tools_data

# %%
experiment_set = "data/payloadFewV3"
experiments = tools_data.getExperimentsInSet(experiment_set)

# %%
experiments
# Out:
# ['5_200_4500_1_0_0_1_20210914_1314',
#  '5_200_4500_1_0_0_10_20210914_1347',
#  '5_200_4500_1_0_0_100_20210914_1421',
#  '5_200_4500_1_0_0_1000_20210914_1454']

# %%
for experiment in experiments:
    print(experiment)
    consumer = tools_data.readConsumer(experiment_set, experiment)
    device_aggregate = tools_data.readAggregateDevices(experiment_set, experiment)
    tools_graph.graphType1(device_aggregate, consumer, experiment)
    tools_graph.graphType2(consumer, experiment)
# Out:
# 5_200_4500_1_0_0_1_20210914_1314
# 5_200_4500_1_0_0_10_20210914_1347
# 5_200_4500_1_0_0_100_20210914_1421
# 5_200_4500_1_0_0_1000_20210914_1454

# %%
tools_graph.graphType3(experiment_set, 6, "Payload", experiment_set, lambda params: int(params[6]))

# %%
tools_graph.graphType4(experiment_set, 6, "Payload", experiment_set, lambda params: int(params[6]))
